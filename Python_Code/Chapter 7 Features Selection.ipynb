# %% [markdown]
# # Supervised and Unsupervised Selection
#
# Please refer to **Chapter 4 Singular Value Decomposition** at **Mutilinear Regression: Example 2** to know more about this

# %% [markdown]
# # Numerical Input, Output

# %%
# Calculate the Pearson's correlation between two variables
from numpy.random import randn
from numpy.random import seed
from scipy.stats import pearsonr
from scipy.stats import spearmanr
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)
# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('Pearsons correlation: %.3f' % corr)
#calculate spearman's correlation
corr1, _ = spearmanr(data1, data2)
print('Spearmans correlation: %.3f' % corr1)
# Out:
# Pearsons correlation: 0.888
# Spearmans correlation: 0.872

# %% [markdown]
# # Calculation of Correlation Statistic by using Python
#
# Please refer to **Chapter 4 Singular Value Decomposition** at **Mutilinear Regression: Example 2 - Data analysis**
# to know more about this

# %% [markdown]
# # Features selection by using ANOVA

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import matplotlib.pyplot as plt

# load the iris dataset as an example
iris = load_iris()
X = iris.data
y = iris.target

# select top 2 features using ANOVA F-value
selector = SelectKBest(f_classif, k="all")
X_new = selector.fit_transform(X, y)

# get the selected features
mask = selector.get_support()
selected_features = np.array(iris.feature_names)[np.where(mask)]
scores = selector.scores_
# print("Selected features:", selected_features)
features_scores = np.column_stack((selected_features, scores[np.where(mask)]))
print("Selected features and scores: \n", features_scores)
# print(scores)
# plot the ANOVA F-value scores
plt.barh(selected_features, scores[mask])
plt.xlabel("ANOVA F-value")
plt.title("ANOVA F-value scores for iris dataset features")
plt.show()
# Out:
# Selected features and scores:
#  [['sepal length (cm)' '119.26450218449871']
#  ['sepal width (cm)' '49.16004008961098']
#  ['petal length (cm)' '1180.1611822529776']
#  ['petal width (cm)' '960.0071468018025']]

# %% [markdown]
# # Dimensionality Reduction
#
# For the **Principal Component Analysis (PCA)**, please refer to **Chapter 4 Singular Value Decomposition** at **Example: Breast Cancer Data** to know more how to implement it using Python
